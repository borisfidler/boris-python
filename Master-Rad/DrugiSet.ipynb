# %%
import numpy as np
import scipy
import pandas as pd
import math
import random
import sklearn
from nltk.corpus import stopwords
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from scipy.sparse.linalg import svds
import matplotlib.pyplot as plt
#include libraries
import csv # to open/close/append CSV
import os # to check if file exists
import nltk #natural language toolkit
from datetime import datetime
import re
from collections import Counter, defaultdict 
from glob import glob
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('darkgrid')

# %%
user_rating_df = pd.read_csv('/Users/boris/Downloads/user_rating_dice.csv', sep=',', header='infer')
user_rating_df.head(5)
# Out:
#                             uniq_id eventType  user_id
# 0  fffe1767dbc1713944851a0a4f02ec5b      LIKE   101131
# 1  fffe1767dbc1713944851a0a4f02ec5b      LIKE   100110
# 2  fffe1767dbc1713944851a0a4f02ec5b      VIEW   100110
# 3  fffd6e0361c1aecb4d099f6465392a77    FOLLOW   101320
# 4  fffd6e0361c1aecb4d099f6465392a77    FOLLOW   100320

# %%
event_type_strength = {
   'VIEW': 1.0,
   'LIKE': 2.0, 
   'BOOKMARK': 3.0, 
   'FOLLOW': 4.0,
   'COMMENT': 5.0,  
}

# %%
user_rating_df['eventStrength'] = user_rating_df['eventType'].apply(lambda x: event_type_strength[x])

# %%
user_rating_df.head(5)
# Out:
#                             uniq_id eventType  user_id  eventStrength
# 0  fffe1767dbc1713944851a0a4f02ec5b      LIKE   101131            2.0
# 1  fffe1767dbc1713944851a0a4f02ec5b      LIKE   100110            2.0
# 2  fffe1767dbc1713944851a0a4f02ec5b      VIEW   100110            1.0
# 3  fffd6e0361c1aecb4d099f6465392a77    FOLLOW   101320            3.0
# 4  fffd6e0361c1aecb4d099f6465392a77    FOLLOW   100320            3.0

# %%
user_rating_count_df = user_rating_df.groupby(['user_id', 'uniq_id']).size().groupby('user_id').size()
print('# users: %d' % len(user_rating_count_df))
user_with_enough_ratings_df = user_rating_count_df[user_rating_count_df >= 25].reset_index()[['user_id']]
print('# users with at least 25 ratings: %d' % len(user_with_enough_ratings_df))
# Out:
# # users: 1501
# # users with at least 25 ratings: 1209

# %%
CSV_file_df = pd.read_csv('/Users/boris/Downloads/dice_com-job_us_sample.csv', sep=',', header='infer')

# %%
CSV_file2_df = CSV_file_df.apply(lambda x: x.astype(str).str.lower())

# %%
CSV_file2_df['jobid'] = CSV_file2_df['jobid'].map(lambda x: x.lstrip('dice id :'))

# %%
from nltk.corpus import stopwords

# %%
stop_words = set(stopwords.words('english'))
CSV_file2_df['Job_Description_Without_Stopwords'] = CSV_file2_df['jobdescription'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop_words)]))
CSV_file2_df['Job_Skills_Without_Stopwords'] = CSV_file2_df['skills'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop_words)]))


#regular expresion in wich we swap all special charachters with a blank and all numbers with a blank also
def clean_string(strings):
    result = []
    for value in strings:
        value = value.strip()
        value = re.sub('([!?\',*+.$-/])',' ', value)
        value = re.sub("\d+", "", value)
        result.append(value)
    return result

# creates list where each document is an element
CSV_file2_df['Job_Description_Without_Stopwords'] = clean_string(CSV_file2_df['Job_Description_Without_Stopwords'])
CSV_file2_df['Job_Skills_Without_Stopwords'] = clean_string(CSV_file2_df['Job_Skills_Without_Stopwords'])

# %%
#ovo gore sam mogao i posle

# %%
print('# of interactions: %d' % len(user_rating_df))
ratings_from_selected_users_df = user_rating.merge(user_with_enough_ratings_df, 
               how = 'right',
               left_on = 'user_id',
               right_on = 'user_id')
print('# of interactions from users with at least 25 interactions: %d' % len(ratings_from_selected_users_df))
# Out:
# # of interactions: 66000
# # of interactions from users with at least 25 interactions: 56472

# %%
def smooth_user_preference(x):
    return math.log(1+x, 2)
    
rating_full_df = ratings_from_selected_users_df \
                    .groupby(['user_id', 'uniq_id'])['eventStrength'].sum() \
                    .apply(smooth_user_preference).reset_index()
print('# of unique user/item ratings: %d' % len(rating_full_df))
rating_full_df.head(10)
# Out:
# # of unique user/item ratings: 37631
#    user_id                           uniq_id  eventStrength
# 0   100000  0f350d3a20b61289bd882547210090b4       1.807355
# 1   100000  29517932e0cc69b7f93196b101ac55fb       3.169925
# 2   100000  2960929545141233ae4185317727842e       1.807355
# 3   100000  2b574988cc462c5f5f1d0cfe81db909d       2.321928
# 4   100000  361514035c6ea8b06d07a285548b4d7a       1.000000
# 5   100000  397a3f1d0d9366ee899b523b36b2b800       1.807355
# 6   100000  3d4f800b32b1a0a5388bac60bbf27b8c       2.807355
# 7   100000  3d8b1489c2b2fbacc2b56f899f529185       1.807355
# 8   100000  3e4e15ab2e9f0543916bc84a82a66166       2.000000
# 9   100000  3f50d0d0c793a0ab1470438ae89cb66a       2.807355

# %%
rating_train_df, rating_test_df = train_test_split(rating_full_df,
                                   stratify=rating_full_df['user_id'], 
                                   test_size=0.20,
                                   random_state=42)

print('# ratings on Train set: %d' % len(rating_train_df))
print('# ratings on Test set: %d' % len(rating_test_df))
# Out:
# # ratings on Train set: 30104
# # ratings on Test set: 7527

# %%
#Indexing by user_id to speed up the searches during evaluation
rating_full_indexed_df = rating_full_df.set_index('user_id')
rating_train_indexed_df = rating_train_df.set_index('user_id')
rating_test_indexed_df = rating_test_df.set_index('user_id')

# %%
def get_items_rating(person_id, user_rating_df):
    # Get the user's data and merge in the movie information.
    rating_items = user_rating_df.loc[person_id]['uniq_id']
    return set(rating_items if type(rating_items) == pd.Series else [rating_items])

# %%
#Top-N accuracy metrics consts
EVAL_RANDOM_SAMPLE_NON_INTERACTED_ITEMS = 100

class ModelEvaluator:


    def get_not_interacted_items_sample(self, person_id, sample_size, seed=42):
        interacted_items = get_items_rating(person_id, rating_full_indexed_df)
        all_items = set(CSV_file2_df['uniq_id'])
        non_interacted_items = all_items - interacted_items

        random.seed(seed)
        non_interacted_items_sample = random.sample(non_interacted_items, sample_size)
        return set(non_interacted_items_sample)

    def _verify_hit_top_n(self, item_id, recommended_items, topn):        
            try:
                index = next(i for i, c in enumerate(recommended_items) if c == item_id)
            except:
                index = -1
            hit = int(index in range(0, topn))
            return hit, index

    def evaluate_model_for_user(self, model, person_id):
        #Getting the items in test set
        interacted_values_testset = rating_test_indexed_df.loc[person_id]
        if type(interacted_values_testset['uniq_id']) == pd.Series:
            person_interacted_items_testset = set(interacted_values_testset['uniq_id'])
        else:
            person_interacted_items_testset = set([int(interacted_values_testset['uniq_id'])])  
        interacted_items_count_testset = len(person_interacted_items_testset) 

        #Getting a ranked recommendation list from a model for a given user
        person_recs_df = model.recommend_items(person_id, 
                                               items_to_ignore=get_items_rating(person_id, 
                                                                                    rating_train_indexed_df), 
                                               topn=10000000000)

        hits_at_5_count = 0
        hits_at_10_count = 0
        #For each item the user has interacted in test set
        for item_id in person_interacted_items_testset:
            #Getting a random sample (100) items the user has not interacted 
            #(to represent items that are assumed to be no relevant to the user)
            non_interacted_items_sample = self.get_not_interacted_items_sample(person_id, 
                                                                          sample_size=EVAL_RANDOM_SAMPLE_NON_INTERACTED_ITEMS, 
                                                                          seed=100000%(2**32))

            #Combining the current interacted item with the 100 random items
            items_to_filter_recs = non_interacted_items_sample.union(set([item_id]))

            #Filtering only recommendations that are either the interacted item or from a random sample of 100 non-interacted items
            valid_recs_df = person_recs_df[person_recs_df['uniq_id'].isin(items_to_filter_recs)]                    
            valid_recs = valid_recs_df['uniq_id'].values
            #Verifying if the current interacted item is among the Top-N recommended items
            hit_at_5, index_at_5 = self._verify_hit_top_n(item_id, valid_recs, 5)
            hits_at_5_count += hit_at_5
            hit_at_10, index_at_10 = self._verify_hit_top_n(item_id, valid_recs, 10)
            hits_at_10_count += hit_at_10

        #Recall is the rate of the interacted items that are ranked among the Top-N recommended items, 
        #when mixed with a set of non-relevant items
        recall_at_5 = hits_at_5_count / float(interacted_items_count_testset)
        recall_at_10 = hits_at_10_count / float(interacted_items_count_testset)

        person_metrics = {'hits@5_count':hits_at_5_count, 
                          'hits@10_count':hits_at_10_count, 
                          'interacted_count': interacted_items_count_testset,
                          'recall@5': recall_at_5,
                          'recall@10': recall_at_10}
        return person_metrics

    def evaluate_model(self, model):
        #print("Running evaluation for users")
        people_metrics = []
        for idx, person_id in enumerate(list(rating_test_indexed_df.index.unique().values)):

            person_metrics = self.evaluate_model_for_user(model, person_id)  
            person_metrics['_person_id'] = person_id
            people_metrics.append(person_metrics)
        print('%d users processed' % idx)

        detailed_results_df = pd.DataFrame(people_metrics) \
                            .sort_values('interacted_count', ascending=False)
        
        global_recall_at_5 = detailed_results_df['hits@5_count'].sum() / float(detailed_results_df['interacted_count'].sum())
        global_recall_at_10 = detailed_results_df['hits@10_count'].sum() / float(detailed_results_df['interacted_count'].sum())
        
        global_metrics = {'modelName': model.get_model_name(),
                          'recall@5': global_recall_at_5,
                          'recall@10': global_recall_at_10}    
        return global_metrics, detailed_results_df
    
model_evaluator = ModelEvaluator()

# %%
CSV_file2_df
# Out:
#                                            advertiserurl  \
# 0      https://www.dice.com/jobs/detail/automation-te...
# 1      https://www.dice.com/jobs/detail/information-s...
# 2      https://www.dice.com/jobs/detail/business-solu...
# 3      https://www.dice.com/jobs/detail/java-develope...
# 4      https://www.dice.com/jobs/detail/devops-engine...
# 5      https://www.dice.com/jobs/detail/sap-fico-arch...
# 6      https://www.dice.com/jobs/detail/network-engin...
# 7      https://www.dice.com/jobs/detail/sr.-web-appli...
# 8      https://www.dice.com/jobs/detail/front-end-dev...
# 9      https://www.dice.com/jobs/detail/application-s...
# 10     https://www.dice.com/jobs/detail/openstack-eng...
# 11     https://www.dice.com/jobs/detail/9001-data-sec...
# 12     https://www.dice.com/jobs/detail/software-engi...
# 13     https://www.dice.com/jobs/detail/sales-enginee...
# 14     https://www.dice.com/jobs/detail/project-manag...
# 15     https://www.dice.com/jobs/detail/windows-syste...
# 16     https://www.dice.com/jobs/detail/test-lead-%25...
# 17     https://www.dice.com/jobs/detail/principal-app...
# 18     https://www.dice.com/jobs/detail/messaging-adm...
# 19     https://www.dice.com/jobs/detail/java-architec...
# 20     https://www.dice.com/jobs/detail/it-business-a...
# 21     https://www.dice.com/jobs/detail/it-sales-mana...
# 22     https://www.dice.com/jobs/detail/sr.-systems-t...
# 23     https://www.dice.com/jobs/detail/it-quality-co...
# 24     https://www.dice.com/jobs/detail/usb-validatio...
# 25     https://www.dice.com/jobs/detail/senior-produc...
# 26     https://www.dice.com/jobs/detail/frontend%2526...
# 27     https://www.dice.com/jobs/detail/1001-selenium...
# 28     https://www.dice.com/jobs/detail/fireeeye-hx-%...
# 29     https://www.dice.com/jobs/detail/sr.-software-...
# ...                                                  ...
# 21970  https://www.dice.com/jobs/detail/project-manag...
# 21971  https://www.dice.com/jobs/detail/peoplesoft-ab...
# 21972  https://www.dice.com/jobs/detail/sr.-software-...
# 21973  https://www.dice.com/jobs/detail/senior-techni...
# 21974  https://www.dice.com/jobs/detail/full-stack-de...
# 21975  https://www.dice.com/jobs/detail/go%2526%25234...
# 21976  https://www.dice.com/jobs/detail/senior-full-s...
# 21977  https://www.dice.com/jobs/detail/software-deve...
# 21978  https://www.dice.com/jobs/detail/lead-splunk-e...
# 21979  https://www.dice.com/jobs/detail/project-manag...
# 21980  https://www.dice.com/jobs/detail/senior-softwa...
# 21981  https://www.dice.com/jobs/detail/sales-operati...
# 21982  https://www.dice.com/jobs/detail/sr-android-de...
# 21983  https://www.dice.com/jobs/detail/senior-projec...
# 21984  https://www.dice.com/jobs/detail/hardware-veri...
# 21985  https://www.dice.com/jobs/detail/alfresco-expe...
# 21986  https://www.dice.com/jobs/detail/.net%2526%252...
# 21987  https://www.dice.com/jobs/detail/network-engin...
# 21988  https://www.dice.com/jobs/detail/ssis-develolp...
# 21989  https://www.dice.com/jobs/detail/windows-deskt...
# 21990  https://www.dice.com/jobs/detail/asic-verifica...
# 21991  https://www.dice.com/jobs/detail/business-anal...
# 21992  https://www.dice.com/jobs/detail/video-process...
# 21993  https://www.dice.com/jobs/detail/sales-account...
# 21994  https://www.dice.com/jobs/detail/empower--admi...
# 21995  https://www.dice.com/jobs/detail/web-designer-...
# 21996  https://www.dice.com/jobs/detail/senior-front-...
# 21997  https://www.dice.com/jobs/detail/qa-analyst-sa...
# 21998  https://www.dice.com/jobs/detail/tech-lead%252...
# 21999  https://www.dice.com/jobs/detail/c%2526%252347...
#
#                                    company  \
# 0        digital intelligence systems, llc
# 1        university of chicago/it services
# 2                     galaxy systems, inc.
# 3                            transtech llc
# 4                         matrix resources
# 5                        yash technologies
# 6                                   noble1
# 7                  bluebeam software, inc.
# 8                                genesis10
# 9          vanderhouwen & associates, inc.
# 10                           maxonic, inc.
# 11       csi (consultant specialists inc.)
# 12         vanderhouwen & associates, inc.
# 13                               genesis10
# 14         vanderhouwen & associates, inc.
# 15           eastridge workforce solutions
# 16                               collabera
# 17         vanderhouwen & associates, inc.
# 18                               genesis10
# 19     fahrenheit it staffing & consulting
# 20                               genesis10
# 21           eastridge workforce solutions
# 22                avesta computer services
# 23                               genesis10
# 24         vanderhouwen & associates, inc.
# 25                                  amazon
# 26         vanderhouwen & associates, inc.
# 27                           reqroute, inc
# 28                     turnberry solutions
# 29         vanderhouwen & associates, inc.
# ...                                    ...
# 21970                            vivo inc.
# 21971                                  erp
# 21972                         bridge noble
# 21973                           wipro ltd.
# 21974                       mindsource inc
# 21975         proactive technical services
# 21976                      net2source inc.
# 21977                       bracket global
# 21978                         covetus, llc
# 21979            connectpoint search group
# 21980             u.s. tech solutions inc.
# 21981                         ommeher inc.
# 21982                   adi worldlink, llc
# 21983                               gsrinc
# 21984                osi engineering, inc.
# 21985                        ab star group
# 21986                               sapvix
# 21987                         trinova, llc
# 21988              mphasis corporation usa
# 21989                 uswired incorporated
# 21990  test and verification solutions llc
# 21991                           wipro ltd.
# 21992              tandem recruiting group
# 21993                             qct, llc
# 21994                         snw infotech
# 21995                       iac publishing
# 21996                  omega solutions inc
# 21997            san francisco health plan
# 21998                       iac publishing
# 21999            technology resource group
#
#                                 employmenttype_jobstatus  \
# 0      c2h corp-to-corp, c2h independent, c2h w2, 3 m...
# 1                                              full time
# 2                                              full time
# 3                                              full time
# 4                                              full time
# 5                                   full time, permanant
# 6                                 full time, direct hire
# 7                                   full time, full time
# 8                            full time, direct placement
# 9                               c2h w2, contract to hire
# 10                                             full time
# 11     full time, contract corp-to-corp, contract ind...
# 12                                  full time, full time
# 13                           full time, direct placement
# 14                                 contract w2, contract
# 15                           full time, contract-to-hire
# 16                                           contract w2
# 17                                  full time, full time
# 18                           full time, direct placement
# 19                                full time, direct hire
# 20                                             full time
# 21                                full time, direct hire
# 22                                       full time, perm
# 23                              full time, right to hire
# 24                                  full time, full time
# 25                                  full time, full time
# 26                                 contract w2, contract
# 27                                             full time
# 28                      c2h independent, c2h w2, 12+ mos
# 29                                  full time, full time
# ...                                                  ...
# 21970  contract corp-to-corp, contract independent, c...
# 21971  contract corp-to-corp, contract independent, c...
# 21972                                          full time
# 21973                                          full time
# 21974  contract corp-to-corp, contract independent, c...
# 21975      contract corp-to-corp, contract w2, 12 months
# 21976  contract corp-to-corp, contract independent, c...
# 21977                                          full time
# 21978  full time, contract corp-to-corp, contract ind...
# 21979                                          full time
# 21980                             contract w2, 06 months
# 21981                             contract w2, 6+ months
# 21982          full time, contract w2, c2h w2, permanent
# 21983                         contract w2, 6 months plus
# 21984  contract corp-to-corp, contract independent, c...
# 21985  contract corp-to-corp, contract independent, c...
# 21986                 contract corp-to-corp, contract w2
# 21987                                     full time, fte
# 21988                                          full time
# 21989                                          full time
# 21990            full time, contract w2, c2h w2, 1+ year
# 21991                                          full time
# 21992                                          full time
# 21993                                          full time
# 21994  contract corp-to-corp, contract independent, c...
# 21995                                          full time
# 21996                                          full time
# 21997                                          full time
# 21998                                          full time
# 21999                               full time, full time
#
#                                           jobdescription      jobid  \
# 0      looking for selenium engineers...must have sol...   10110693
# 1      the university of chicago has a rapidly growin...   10114469
# 2      galaxe.solutionsevery day, our solutions affec...    xgalxys
# 3      java developerfull-time/direct-hirebolingbrook...   10113627
# 4      midtown based high tech firm has an immediate ...   matrixga
# 5      we are looking for a senior sap fico architect...   10111847
# 6      network engineer job description a network eng...   90884761
# 7      bluebeam is looking for talented sr. web devel...   10110132
# 8      this is a fulltime position for a javascript d...   gentx001
# 9      summaryour client is the leading provider of o...    vhassoc
# 10     job description:as a senior member of the team...   10108942
# 11     must have skills: unix, iam (identity access m...   10106409
# 12     vanderhouwen has more jobs you may like!  find...    vhassoc
# 13     genesis10 is currently seeking a sales enginee...   gentx001
# 14     vanderhouwen has more jobs you may like! find ...    vhassoc
# 15     windows systems administrator the windows syst...      astsd
# 16     location atlanta, gajob title test lead / mana...  10208346j
# 17     vanderhouwen has more jobs you may like!  find...    vhassoc
# 18     genesis10 is actively seeking a messaging admi...   gentx001
# 19     our client in the healthcare software industry...   10111360
# 20     genesis10 is looking for a business analyst fo...   gentx001
# 21     great opportunity for driven, energetic it sal...      astsd
# 22     our client is the world’s premier voice and el...     avesta
# 23     genesis10 is seeking an it quality consultant ...   gentx001
# 24     vanderhouwen has more jobs you may like!  find...    vhassoc
# 25     do you want a chance to directly improve the c...   amazsell
# 26     please join our talent network: http://bit.ly/...    vhassoc
# 27     selenium testersalt lake city , ut & phoenix ,...   10349715
# 28      turnberry solutions is in search of a securit...   10120009
# 29     please join our talent network: http://bit.ly/...    vhassoc
# ...                                                  ...        ...
# 21970  our client, a highly regarded leader in its in...   10126416
# 21971  hi,   greetings from erp analysts inc,we have ...   10114195
# 21972  sr. software engineer - node.js - leading hosp...   10504574
# 21973  senior technical architect – account focus. jo...   10110759
# 21974  full stack developer will work on both front e...      minds
# 21975  go/golang software engineerlocation: palo alto...   10331486
# 21976  net2source, inc. is one of the fastest growing...   10271304
# 21977  realize your true potential at bracket!our goa...   10463394
# 21978  greetingsone of our clients is hiring lead spl...   10508656
# 21979  connectpoint search group is looking for a pro...   10226311
# 21980  us tech solutions is seeking a “senior softwar...       usts
# 21981  the client ww sales operations team is looking...   10410997
# 21982  our client located is recruiting an exceptiona...   10118594
# 21983  my client is looking for a seniorl project man...        gsr
# 21984  hardware verification, system verilog engineer...   10365912
# 21985  hope you are doing good!we have an urgent posi...   10119900
# 21986  hi ,greetings!!! this is praveenfrom aptus it ...   10350483
# 21987  our client is looking for a network engineer t...    trinova
# 21988  more than 8+ years exp on sql server and msbi ...  501494924
# 21989  windows desktop support engineer - sj about us...  rtx15cc9b
# 21990  test and verification solutions (t&vs) - uk ba...   90918052
# 21991  job type: full timejob location: san mateo, ca...   10110759
# 21992  video software engineer: we are seeking an exc...   10111438
# 21993  4 position availablecompany information:  qct ...   10506283
# 21994  •     hands on experience in csv, performing i...   90614078
# 21995   company description we are searching for a ta...   10112803
# 21996   contact - priya@omegasolutioninc.com / 408-45...   10289500
# 21997  do you take pride in your work knowing that th...   10115761
# 21998  company description what we can offer youas th...   10112803
# 21999  experience in c/c++ programmingdevelopment exp...   90734436
#
#        joblocation_address                                           jobtitle  \
# 0              atlanta, ga                           automation test engineer
# 1              chicago, il                      information security engineer
# 2           schaumburg, il                       business solutions architect
# 3          bolingbrook, il  java developer (mid level)- ft- great culture,...
# 4              atlanta, ga                                    devops engineer
# 5              chicago, il                                 sap fico architect
# 6              atlanta, ga                                   network engineer
# 7              chicago, il  sr. web application developer (cloud team) - c...
# 8             new york, ny                                front end developer
# 9              seattle, wa                       application support engineer
# 10           sunnyvale, ca                         openstack engineer - 12185
# 11     highlands ranch, co      9001 data security administrator - unix & iam
# 12            portland, or                          software engineer manager
# 13         los angeles, ca                        sales engineer - los angles
# 14           hillsboro, or                                    project manager
# 15           las vegas, nv                       windows system administrator
# 16             atlanta, ga                           test lead / test manager
# 17           beaverton, or  principal application analyst-supply chain lawson
# 18         kansas city, mo                            messaging administrator
# 19              denver, co             java architect - denver, co - fulltime
# 20       sandy springs, ga                                it business analyst
# 21             chicago, il                                   it sales manager
# 22          parsippany, nj                   sr. systems test engineer (perm)
# 23        eden prairie, mn                              it quality consultant
# 24              austin, tx                            usb validation engineer
# 25             seattle, wa                             senior product manager
# 26             seattle, wa                              frontend/ui developer
# 27      salt lake city, ut                   1001 selenium automation testing
# 28            columbia, sc                    fireeeye hx - security engineer
# 29             seattle, wa                      sr. software storage engineer
# ...                    ...                                                ...
# 21970        palo alto, ca                       project manager - lawson erp
# 21971       sacramento, ca                 peoplesoft absence management lead
# 21972    san francisco, ca  sr. software engineer - node.js - leading hosp...
# 21973    mountain view, ca           senior technical architect account focus
# 21974         san jose, ca                    full stack developer (contract)
# 21975        palo alto, ca                        go/golang software engineer
# 21976        san ramon, ca                        senior full stack developer
# 21977    san francisco, ca                                 software developer
# 21978    san francisco, ca               lead splunk engineer- wa, ca, tx, co
# 21979         stockton, ca                                    project manager
# 21980      santa clara, ca                           senior software engineer
# 21981    san francisco, ca                   sales operations project manager
# 21982    mountain view, ca                    sr android developer - smart tv
# 21983    san francisco, ca                             senior project manager
# 21984      santa clara, ca              hardware verification, system verilog
# 21985        san ramon, ca                                    alfresco expert
# 21986    san francisco, ca                            .net/frontend developer
# 21987       santa cruz, ca                                   network engineer
# 21988    san francisco, ca                                    ssis develolper
# 21989         san jose, ca              windows desktop support engineer - sj
# 21990         san jose, ca                         asic verification engineer
# 21991        san mateo, ca                       business analyst (ecommerce)
# 21992        cupertino, ca                             video process engineer
# 21993         san jose, ca                              sales account manager
# 21994      foster city, ca                              empower administrator
# 21995          oakland, ca                                       web designer
# 21996    san francisco, ca  senior front end web developer - full time at ...
# 21997    san francisco, ca                                         qa analyst
# 21998          oakland, ca                               tech lead-full stack
# 21999      santa clara, ca                                   c/c++ programmer
#
#              postdate                                              shift  \
# 0          1 hour ago    telecommuting not available|travel not required
# 1          1 week ago    telecommuting not available|travel not required
# 2         2 weeks ago    telecommuting not available|travel not required
# 3         2 weeks ago    telecommuting not available|travel not required
# 4      48 minutes ago    telecommuting not available|travel not required
# 5         2 weeks ago  telecommuting not available|travel required to...
# 6          1 hour ago    telecommuting not available|travel not required
# 7         2 weeks ago    telecommuting not available|travel not required
# 8         7 hours ago    telecommuting not available|travel not required
# 9         7 hours ago    telecommuting not available|travel not required
# 10        7 hours ago    telecommuting not available|travel not required
# 11        7 hours ago    telecommuting not available|travel not required
# 12        7 hours ago    telecommuting not available|travel not required
# 13        7 hours ago    telecommuting not available|travel not required
# 14        7 hours ago    telecommuting not available|travel not required
# 15        7 hours ago    telecommuting not available|travel not required
# 16        7 hours ago        telecommuting available|travel not required
# 17        7 hours ago    telecommuting not available|travel not required
# 18        7 hours ago    telecommuting not available|travel not required
# 19        7 hours ago    telecommuting not available|travel not required
# 20        7 hours ago    telecommuting not available|travel not required
# 21        7 hours ago    telecommuting not available|travel not required
# 22        7 hours ago    telecommuting not available|travel not required
# 23        7 hours ago    telecommuting not available|travel not required
# 24        7 hours ago    telecommuting not available|travel not required
# 25        7 hours ago    telecommuting not available|travel not required
# 26        7 hours ago    telecommuting not available|travel not required
# 27        7 hours ago    telecommuting not available|travel not required
# 28        6 hours ago    telecommuting not available|travel not required
# 29        7 hours ago    telecommuting not available|travel not required
# ...               ...                                                ...
# 21970     2 weeks ago    telecommuting not available|travel not required
# 21971     2 weeks ago    telecommuting not available|travel not required
# 21972     2 weeks ago    telecommuting not available|travel not required
# 21973     3 weeks ago    telecommuting not available|travel not required
# 21974     2 weeks ago    telecommuting not available|travel not required
# 21975      1 week ago    telecommuting not available|travel not required
# 21976     3 weeks ago    telecommuting not available|travel not required
# 21977      1 week ago    telecommuting not available|travel not required
# 21978     3 weeks ago    telecommuting not available|travel not required
# 21979     2 weeks ago    telecommuting not available|travel not required
# 21980     2 weeks ago    telecommuting not available|travel not required
# 21981     2 weeks ago    telecommuting not available|travel not required
# 21982     3 weeks ago    telecommuting not available|travel not required
# 21983     2 weeks ago    telecommuting not available|travel not required
# 21984     2 weeks ago    telecommuting not available|travel not required
# 21985     2 weeks ago    telecommuting not available|travel not required
# 21986      1 week ago    telecommuting not available|travel not required
# 21987     2 weeks ago    telecommuting not available|travel not required
# 21988     2 weeks ago    telecommuting not available|travel not required
# 21989     2 weeks ago    telecommuting not available|travel not required
# 21990     3 weeks ago    telecommuting not available|travel not required
# 21991     3 weeks ago    telecommuting not available|travel not required
# 21992      1 week ago    telecommuting not available|travel not required
# 21993     3 weeks ago    telecommuting not available|travel not required
# 21994     2 weeks ago    telecommuting not available|travel not required
# 21995     3 weeks ago    telecommuting not available|travel not required
# 21996     3 weeks ago    telecommuting not available|travel not required
# 21997     2 weeks ago    telecommuting not available|travel not required
# 21998     2 weeks ago    telecommuting not available|travel not required
# 21999     2 weeks ago    telecommuting not available|travel not required
#
#       site_name                                             skills  \
# 0           nan                                          see below
# 1           nan  linux/unix, network monitoring, incident respo...
# 2           nan  enterprise solutions architecture, business in...
# 3           nan                         please see job description
# 4           nan  configuration management, developer, linux, ma...
# 5           nan               fico, ar, ap, asset management, haha
# 6           nan  cisco, dns, http, networking, network engineer...
# 7           nan  .net , c#, mvc, restful web services, http, aw...
# 8           nan  c++, developer, development, javascript, user ...
# 9           nan                              (see job description)
# 10          nan                                          openstack
# 11          nan  unix, iam, scripting knowledge, oim, windows, ...
# 12          nan                                          java, oss
# 13          nan         consulting, project, sales, sales engineer
# 14          nan                                      mobile device
# 15          nan                              (see job description)
# 16          nan                                                 qa
# 17          nan                                lawson supply chain
# 18          nan  desktop, hardware, network, software, systems,...
# 19          nan                              (see job description)
# 20          nan  analysis, analyst, application, business analy...
# 21          nan                              (see job description)
# 22          nan  system testing, load/performance testing, fix....
# 23          nan  agile, case, consulting, defect management, ma...
# 24          nan                                    matlab, labview
# 25          nan  do you want a chance to directly improve the c...
# 26          nan             angular.js, react, node.js, javascript
# 27          nan                        selenium testing automation
# 28          nan  (information security over 1 year(s) or cyber ...
# 29          nan                             c and c++, linux, unix
# ...         ...                                                ...
# 21970       nan                     lawson erp, project management
# 21971       nan      peoplesoft absence management functional lead
# 21972       nan                                node.js, javascript
# 21973       nan                                          architect
# 21974       nan                                   php / python / c
# 21975       nan  java, go/golang, and python, go/golang, go/gol...
# 21976       nan                                               null
# 21977       nan                                   .net, sql server
# 21978       nan  lead splunk engineer, architect, splunk, qos,s...
# 21979       nan  project manager, pmp, it, business, documentation
# 21980       nan  ceph, hdfs , c , linux kernel internals, espec...
# 21981       nan  5+ years of pm experience with sales operation...
# 21982       nan                android, app, software, mobile, sdk
# 21983       nan                             project management pmp
# 21984       nan                            verification experience
# 21985       nan    pm/scrum master/qa person with this experience.
# 21986       nan                           ui; .net,javascript;html
# 21987       nan  firewalls, load balancing, routing, switching,...
# 21988       nan                              ssis, ssrs, agile, bi
# 21989       nan           windows desktop support active directory
# 21990       nan  "asic","soc", "verification", "systemverilog",...
# 21991       nan                                  ecommerce, retail
# 21992       nan  expert knowledge of libavcodec, libavformat et...
# 21993       nan  0 - 5 years experience. selling hardware/softw...
# 21994       nan                                    empower3, limps
# 21995       nan  ui/ux mobile apps, interaction design, digital...
# 21996       nan  javascript, html5, css3, bootstrap, ajax, reac...
# 21997       nan  sdlc, alm, sql, t-sql, redgate, team foundatio...
# 21998       nan  python, ruby, go, clojure, java, nosql-databas...
# 21999       nan                                               null
#
#                                 uniq_id  \
# 0      418ff92580b270ef4e7c14f0ddfc36b4
# 1      8aec88cba08d53da65ab99cf20f6f9d9
# 2      46baa1f69ac07779274bcd90b85d9a72
# 3      3941b2f206ae0f900c4fba4ac0b18719
# 4      45efa1f6bc65acc32bbbb953a1ed13b7
# 5      e0ac9d926dda5e95162ef05adea7318c
# 6      e7e326053c586bd94e59f1fd74de4a1b
# 7      b0dadecf4c3c2beecb9c773ca11ecda4
# 8      28f5e0c1cc3314813e674f0c32b04d1b
# 9      95c9127e2770172f454f3b83981eaa88
# 10     5e0ff38f5eaf44726f4e3d1dd257a244
# 11     e4a1ff1b6c0fda5f345e57cf1acb40dd
# 12     d0c81a2e3e5d666f3d730f1048c49132
# 13     51279d060da242e3baea98b26ddd641e
# 14     48b7ca0c2f6191fb48e7ecf19fbd3322
# 15     9e5704d08bc07ddb6df9ef98b223b036
# 16     e4dceaaaaae37ca6eabb04a7d42498b4
# 17     7ad2eadde69e07fee0e38c1a251dd81f
# 18     f3af6886ca0d133abda2ddf9b84633e4
# 19     e4f57bc5366124a0a47cac27f557f9ec
# 20     d3073d47b79938269b22bdea4dc0b9b8
# 21     c014c8569c91f22bc871940bfa4b4296
# 22     b7fab2d3de5e129310b382d8f51508f6
# 23     4868383e3f99535778f354fcb734d57c
# 24     81f8732626888727fcc1093b6c084839
# 25     cf902dc6fd702207563ed1cdc03ef05e
# 26     1bef3cf6259e80d18222407858ad9052
# 27     72a3f0f0f24a0a78c5fac3c2376f5979
# 28     4a3f8742fae151757eb290a774968371
# 29     b1db84e23f424b1481b29212749abadc
# ...                                 ...
# 21970  eb93c8d237a8aacc2b741517f40ee190
# 21971  43c4a585f3a42e54d812c2b855e635b0
# 21972  e501c02a4038dd49d420411fc2632ac8
# 21973  c19f4a4369036c47afe4c63c20d2baf2
# 21974  3a0534473ab9c5cc03899a77703bb9e2
# 21975  83d1393d14ae7edbefb719b5f37ecd6d
# 21976  56b2dd205154a1cb2eae101efcd14567
# 21977  f030dd810d86411a93cb5682c0ac35aa
# 21978  fd1e05e481af4a76fcc5a7c49914825b
# 21979  788d893cd6b11dfd5ea921666ee1e009
# 21980  b6b3d382ba66dfe7f80abaaa89a92e3d
# 21981  ab42980a1be610f35939d37527fb72c2
# 21982  8c4e3cfa8afc91c1d002e881b6493b29
# 21983  c5fc49888e42880339d7753fd7559990
# 21984  fc7085f0ab79099a6d87490d27def0c8
# 21985  6cae8f5b52c79e884168d6f9b4962025
# 21986  74262c496c6c04e38a7fbbb4e2e500d4
# 21987  95bebff86da8f10232e75d24a94297d3
# 21988  9a415ba24303aa16475f85438fc78921
# 21989  76f85e4cf8b60279811613c7cbe72663
# 21990  ba32786b50e8b4d468cb9d813066fea5
# 21991  541b0f16ecd86fdbd7ee2b04523dc65e
# 21992  ee46660dd5318edb27b229f51341fcf8
# 21993  4b1726afa64b7c9dc640c7862ae64ecc
# 21994  1acc1a7a845f0b9c233ad42941f0462d
# 21995  86e27ce6b7e631e55d69d142c7d43df2
# 21996  4287c7ee3317ccf1edd76e238cf8e584
# 21997  d7512f0181d69f83f96db38cd77a4d08
# 21998  ec375268b494b3bcbed1635d64226112
# 21999  9a4e8c27f74af4c0d2f6efbd420a8a91
#
#                        Job_Description_Without_Stopwords  \
# 0      looking selenium engineers   must solid java c...
# 1      university chicago rapidly growing security pr...
# 2      galaxe solutionsevery day  solutions affect pe...
# 3      java developerfull time direct hirebolingbrook...
# 4      midtown based high tech firm immediate need in...
# 5      looking senior sap fico architect join us full...
# 6      network engineer job description network engin...
# 7      bluebeam looking talented sr  web developers p...
# 8      fulltime position javascript developer financi...
# 9      summaryour client leading provider online vide...
# 10     job description:as senior member team  respons...
# 11     must skills: unix  iam  identity access manage...
# 12     vanderhouwen jobs may like  find here: http:  ...
# 13     genesis currently seeking sales engineer steel...
# 14     vanderhouwen jobs may like  find here:http:  b...
# 15     windows systems administrator windows systems ...
# 16     location atlanta  gajob title test lead   mana...
# 17     vanderhouwen jobs may like  find here: http:  ...
# 18     genesis actively seeking messaging administrat...
# 19     client healthcare software industry seeking ja...
# 20     genesis looking business analyst long term con...
# 21     great opportunity driven  energetic sales prof...
# 22     client world’s premier voice electronic interd...
# 23     genesis seeking quality consultant  month cont...
# 24     vanderhouwen jobs may like  find here: http:  ...
# 25     want chance directly improve customer experien...
# 26     please join talent network: http:  bit ly vhat...
# 27     selenium testersalt lake city   ut   phoenix  ...
# 28     turnberry solutions search security engineer m...
# 29     please join talent network: http:  bit ly vhat...
# ...                                                  ...
# 21970  client  highly regarded leader industry need s...
# 21971  hi  greetings erp analysts inc we urgent requi...
# 21972  sr  software engineer   node js   leading hosp...
# 21973  senior technical architect – account focus  jo...
# 21974  full stack developer work front end back end a...
# 21975  go golang software engineerlocation: palo alto...
# 21976  netsource  inc  one fastest growing consulting...
# 21977  realize true potential bracket our goal  pursu...
# 21978  greetingsone clients hiring lead splunk engine...
# 21979  connectpoint search group looking project mana...
# 21980  us tech solutions seeking “senior software eng...
# 21981  client ww sales operations team looking except...
# 21982  client located recruiting exceptional android ...
# 21983  client looking seniorl project manager  locati...
# 21984  hardware verification  system verilog engineer...
# 21985  hope good we urgent position san ramon  ca   p...
# 21986  hi  greetings    praveenfrom aptus solutions i...
# 21987  client looking network engineer work team supp...
# 21988    years exp sql server msbi  ssis ssas ssrs et...
# 21989  windows desktop support engineer   sj us:uswir...
# 21990  test verification solutions  t vs    uk based ...
# 21991  job type: full timejob location: san mateo  ca...
# 21992  video software engineer: seeking exceptional v...
# 21993   position availablecompany information: qct  q...
# 21994  • hands experience csv  performing installatio...
# 21995  company description searching talented creativ...
# 21996  contact   priya@omegasolutioninc com     locat...
# 21997  take pride work knowing thousands lives positi...
# 21998  company description offer youas world’s leadin...
# 21999  experience c c   programmingdevelopment experi...
#
#                             Job_Skills_Without_Stopwords
# 0                                                    see
# 1      linux unix  network monitoring  incident respo...
# 2      enterprise solutions architecture  business in...
# 3                             please see job description
# 4      configuration management  developer  linux  ma...
# 5                   fico  ar  ap  asset management  haha
# 6      cisco  dns  http  networking  network engineer...
# 7       net   c#  mvc  restful web services  http  aw...
# 8      c    developer  development  javascript  user ...
# 9                                   see job description
# 10                                             openstack
# 11     unix  iam  scripting knowledge  oim  windows  ...
# 12                                             java  oss
# 13            consulting  project  sales  sales engineer
# 14                                         mobile device
# 15                                  see job description
# 16                                                    qa
# 17                                   lawson supply chain
# 18     desktop  hardware  network  software  systems ...
# 19                                  see job description
# 20     analysis  analyst  application  business analy...
# 21                                  see job description
# 22     system testing  load performance testing  fix ...
# 23     agile  case  consulting  defect management  ma...
# 24                                       matlab  labview
# 25     want chance directly improve customer experien...
# 26                angular js  react  node js  javascript
# 27                           selenium testing automation
# 28      information security  year s  cyber security ...
# 29                                    c c    linux  unix
# ...                                                  ...
# 21970                     lawson erp  project management
# 21971      peoplesoft absence management functional lead
# 21972                                node js  javascript
# 21973                                          architect
# 21974                                   php   python   c
# 21975  java  go golang  python  go golang  go golang ...
# 21976                                               null
# 21977                                    net  sql server
# 21978  lead splunk engineer  architect  splunk  qos s...
# 21979  project manager  pmp  it  business  documentation
# 21980  ceph  hdfs   c   linux kernel internals  espec...
# 21981          years pm experience sales operations  pmp
# 21982                android  app  software  mobile  sdk
# 21983                             project management pmp
# 21984                            verification experience
# 21985              pm scrum master qa person experience
# 21986                           ui;  net javascript;html
# 21987  firewalls  load balancing  routing  switching ...
# 21988                              ssis  ssrs  agile  bi
# 21989           windows desktop support active directory
# 21990  "asic" "soc"  "verification"  "systemverilog" ...
# 21991                                  ecommerce  retail
# 21992  expert knowledge libavcodec  libavformat etc r...
# 21993      years experience  selling hardware softwar...
# 21994                                     empower  limps
# 21995  ui ux mobile apps  interaction design  digital...
# 21996  javascript  html  css  bootstrap  ajax  react ...
# 21997  sdlc  alm  sql  t sql  redgate  team foundatio...
# 21998  python  ruby  go  clojure  java  nosql databas...
# 21999                                               null
#
# [22000 rows x 14 columns]

# %%
vectorizer = TfidfVectorizer(analyzer='word',
                     ngram_range=(2, 3),
                     min_df=0.003,
                     max_df=0.5,
                     max_features=5000
                     )

item_ids = CSV_file2_df['uniq_id'].tolist()
tfidf_matrix = vectorizer.fit_transform(CSV_file2_df['Job_Skills_Without_Stopwords']+ "" + CSV_file2_df['Job_Description_Without_Stopwords'])
tfidf_feature_names = vectorizer.get_feature_names()
tfidf_matrix
# Out:
# <22000x5000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1273507 stored elements in Compressed Sparse Row format>

# %%
def get_item_profile(item_id):
    idx = item_ids.index(item_id)
    item_profile = tfidf_matrix[idx:idx+1]
    return item_profile

def get_item_profiles(ids):
    item_profiles_list = [get_item_profile(x) for x in ids]
    item_profiles = scipy.sparse.vstack(item_profiles_list)
    return item_profiles

def build_users_profile(user_id, rating_indexed_df):
    rating_person_df = rating_indexed_df.loc[user_id]
    user_item_profiles = get_item_profiles(rating_person_df['uniq_id'])
    
    user_item_strengths = np.array(rating_person_df['eventStrength']).reshape(-1,1)
    #Weighted average of item profiles by the interactions strength
    user_item_strengths_weighted_avg = np.sum(user_item_profiles.multiply(user_item_strengths), axis=0) / np.sum(user_item_strengths)
    user_profile_norm = sklearn.preprocessing.normalize(user_item_strengths_weighted_avg)
    return user_profile_norm

def build_users_profiles(): 
    rating_indexed_df = rating_full_df[rating_full_df['uniq_id'] \
                                                   .isin(CSV_file2_df['uniq_id'])].set_index('user_id')
    user_profiles = {}
    for user_id in rating_indexed_df.index.unique():
        user_profiles[user_id] = build_users_profile(user_id, rating_indexed_df)
    return user_profiles

# %%
user_profiles = build_users_profiles()
len(user_profiles)
# Out:
# 1209

# %%
myprofile = user_profiles[100118]
print(myprofile.shape)
pd.DataFrame(sorted(zip(tfidf_feature_names, 
                        user_profiles[100118].flatten().tolist()), key=lambda x: -x[1])[:20],
             columns=['token', 'relevance'])
# Out:
# (1, 5000)
#                       token  relevance
# 0          experience using   0.168340
# 1          business objects   0.121086
# 2          years experience   0.120097
# 3           account manager   0.110196
# 4    development experience   0.109406
# 5           ideal candidate   0.107328
# 6        years demonstrated   0.104136
# 7    programming experience   0.104047
# 8                 rest soap   0.099230
# 9                  big data   0.093637
# 10       experience working   0.092999
# 11  demonstrated experience   0.092373
# 12            build release   0.089848
# 13               ruby rails   0.085970
# 14         systems engineer   0.082317
# 15        web services rest   0.082258
# 16         job requirements   0.080051
# 17            services rest   0.079839
# 18                 html css   0.079271
# 19         technologies inc   0.078933

# %%
class ContentBasedRecommender:
    
    MODEL_NAME = 'Content-Based'
    
    def __init__(self, items_df=None):
        self.item_ids = item_ids
        self.items_df = items_df
        
    def get_model_name(self):
        return self.MODEL_NAME
        
    def _get_similar_items_to_user_profile(self, person_id, topn=10):
        #Computes the cosine similarity between the user profile and all item profiles
        cosine_similarities = cosine_similarity(user_profiles[person_id], tfidf_matrix)
        #Gets the top similar items
        similar_indices = cosine_similarities.argsort().flatten()[-topn:]
        #Sort the similar items by similarity
        similar_items = sorted([(item_ids[i], cosine_similarities[0,i]) for i in similar_indices], key=lambda x: -x[1])
        return similar_items
        
    def recommend_items(self, user_id, items_to_ignore=[], topn=10, verbose=False):
        similar_items = self._get_similar_items_to_user_profile(user_id)
        #Ignores items the user has already interacted
        similar_items_filtered = list(filter(lambda x: x[0] not in items_to_ignore, similar_items))
        
        recommendations_df = pd.DataFrame(similar_items_filtered, columns=['uniq_id', 'eventStrength']) \
                                    .head(topn)

        if verbose:
            if self.items_df is None:
                raise Exception('"items_df" is required in verbose mode')

            recommendations_df = recommendations_df.merge(self.items_df, how = 'left', 
                                                          left_on = 'uniq_id', 
                                                          right_on = 'uniq_id')['eventStrength', 'uniq_id']


        return recommendations_df
    
content_based_recommender_model = ContentBasedRecommender(CSV_file2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-81e400bb4d6a> in <module>()
#      37         return recommendations_df
#      38
# ---> 39 content_based_recommender_model = ContentBasedRecommender(CSV_file2)
#
# NameError: name 'CSV_file2' is not defined

# %%
class ContentBasedRecommender:
    
    MODEL_NAME = 'Content-Based'
    
    def __init__(self, items_df=None):
        self.item_ids = item_ids
        self.items_df = items_df
        
    def get_model_name(self):
        return self.MODEL_NAME
        
    def _get_similar_items_to_user_profile(self, person_id, topn=1000):
        #Computes the cosine similarity between the user profile and all item profiles
        cosine_similarities = cosine_similarity(user_profiles[person_id], tfidf_matrix)
        #Gets the top similar items
        similar_indices = cosine_similarities.argsort().flatten()[-topn:]
        #Sort the similar items by similarity
        similar_items = sorted([(item_ids[i], cosine_similarities[0,i]) for i in similar_indices], key=lambda x: -x[1])
        return similar_items
        
    def recommend_items(self, user_id, items_to_ignore=[], topn=10, verbose=False):
        similar_items = self._get_similar_items_to_user_profile(user_id)
        #Ignores items the user has already interacted
        similar_items_filtered = list(filter(lambda x: x[0] not in items_to_ignore, similar_items))
        
        recommendations_df = pd.DataFrame(similar_items_filtered, columns=['uniq_id', 'recStrength']) \
                                    .head(topn)

        if verbose:
            if self.items_df is None:
                raise Exception('items_df is required in verbose mode')

            recommendations_df = recommendations_df.merge(self.items_df, how = 'left', 
                                                          left_on = 'uniq_id', 
                                                          right_on = 'uniq_id')[['eventStrength', 'uniq_id']]


        return recommendations_df
    
content_based_recommender_model = ContentBasedRecommender(CSV_file2_df)

# %%
cb_global_metrics, cb_detailed_results_df = model_evaluator.evaluate_model(content_based_recommender_model)

cb_detailed_results_df.head(10)
# Out:
# 1208 users processed
#       _person_id  hits@10_count  hits@5_count  interacted_count  recall@10  \
# 56        100003              8             7                10   0.800000
# 1037      100138              7             7                10   0.700000
# 351       101190              8             8                10   0.800000
# 14        100772              9             6                10   0.900000
# 107       100559              7             7                10   0.700000
# 329       100642              7             7                 9   0.777778
# 933       100824              7             7                 9   0.777778
# 124       100672              8             8                 9   0.888889
# 310       100411              5             5                 9   0.555556
# 311       100190              8             8                 9   0.888889
#
#       recall@5
# 56    0.700000
# 1037  0.700000
# 351   0.800000
# 14    0.600000
# 107   0.700000
# 329   0.777778
# 933   0.777778
# 124   0.888889
# 310   0.555556
# 311   0.888889

# %%
non_interacted_items_sample
